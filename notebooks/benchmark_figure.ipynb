# %%
from om_decoder.bionano_compare import *

report = BionanoCompareReport()
report.run_name = "20221014T092718Z"
report.read_compute_results()
report.compute_accuracy()

# %%
report.plot_compare()
pyplot.gcf().set_figheight(5)
pyplot.gcf().set_figwidth(10)
pyplot.gcf().set_dpi(400)

for ext in [".pdf", ".jpg"]:
    pyplot.savefig(Path("../figures") / ("benchmark_figure" + ext))
